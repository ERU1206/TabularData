# %%
run plot_surface1.py --mpi --model resnet56 --x=-1:1:51 --y=-1:1:51 --model_file cifar10/trained_nets/resnet56_sgd_lr=0.1_bs=128_wd=0.0005/model_sl.t7 --dir_type weights --plot
# Out:
# -------------------------------------------------------------------
# setup_direction
# -------------------------------------------------------------------
# Setting up the plotting directions...
# direction file created: cifar10/trained_nets/resnet56_sgd_lr=0.1_bs=128_wd=0.0005/model_sl.t7_weights.h5
# cosine similarity between x-axis and y-axis: -0.007598
# Files already downloaded and verified
# Files already downloaded and verified
# Computing 2601 values for rank 0
# Evaluating rank 0  0/2601  (0.0%)  coord=[-1. -1.] 	train_loss= 0.004 	train_acc=61.29 	time=7.01 	sync=0.00
# Evaluating rank 0  1/2601  (0.0%)  coord=[-0.96 -1.  ] 	train_loss= 0.004 	train_acc=61.77 	time=6.83 	sync=0.00
# Evaluating rank 0  2/2601  (0.1%)  coord=[-0.92 -1.  ] 	train_loss= 0.004 	train_acc=62.41 	time=6.54 	sync=0.00
# Evaluating rank 0  3/2601  (0.1%)  coord=[-0.88 -1.  ] 	train_loss= 0.005 	train_acc=63.31 	time=6.68 	sync=0.00
# ...

# %%
run h52vtp.py --surf_file  cifar10/trained_nets/resnet56_sgd_lr=0.1_bs=128_wd=0.0005/model_sl.t7_weights.h5_[-1.0,1.0,51]x[-1.0,1.0,51].h5 --surf_name train_loss --zmax  10 --log
# Out:
# Here's your output file:cifar10/trained_nets/resnet56_sgd_lr=0.1_bs=128_wd=0.0005/model_sl.t7_weights.h5_[-1.0,1.0,51]x[-1.0,1.0,51].h5_train_loss_zmax=10.0_log.vtp
# number_points = 2601 points
# matrix_size = 51 x 51
# poly_size = 50 x 50
# number_polys = 2500
# Done with file:cifar10/trained_nets/resnet56_sgd_lr=0.1_bs=128_wd=0.0005/model_sl.t7_weights.h5_[-1.0,1.0,51]x[-1.0,1.0,51].h5_train_loss_zmax=10.0_log.vtp
# /home/jovyan/nas/1_user/dskim@agilesoda.ai/h52vtp.py:115: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 0:
# /home/jovyan/nas/1_user/dskim@agilesoda.ai/h52vtp.py:118: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if (vertexcount % 6) is 5:
# /home/jovyan/nas/1_user/dskim@agilesoda.ai/h52vtp.py:122: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (vertexcount % 6) is not 5:
# /home/jovyan/nas/1_user/dskim@agilesoda.ai/h52vtp.py:132: SyntaxWarning: "is" with a literal. Did you mean "=="?
# ...

# %%
7 * 2600
# Out:
# 18200

# %%
18200 / 3600
# Out:
# 5.055555555555555

# %%
5시간..
